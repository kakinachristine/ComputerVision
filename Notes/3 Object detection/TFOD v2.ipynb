# %%
import cv2, time, os, tensorflow as tf, numpy as np
from tensorflow.python.keras.utils.data_utils import get_file

# %%
# file containing list of objects
class_file= "coco.names"

# %%
# create a list of objects
with open(class_file,'r') as f:
    class_list=f.read().splitlines()
class_list
# Out:
# ['__Background__',
#  ' person',
#  ' bicycle',
#  ' car',
#  ' motorcycle',
#  ' airplane',
#  ' bus',
#  ' train',
#  ' truck',
#  ' boat',
#  ' traffic light',
#  ' fire hydrant',
#  ' street sign',
#  ' stop sign',
#  ' parking meter',
#  ' bench',
#  ' bird',
#  ' cat',
#  ' dog',
#  ' horse',
#  ' sheep',
#  ' cow',
#  ' elephant',
#  ' bear',
#  ' zebra',
#  ' giraffe',
#  ' hat',
#  ' backpack',
#  ' umbrella',
#  ' shoe',
#  ' eye glasses',
#  ' handbag',
#  ' tie',
#  ' suitcase',
#  ' frisbee',
#  ' skis',
#  ' snowboard',
#  ' sports ball',
#  ' kite',
#  ' baseball bat',
#  ' baseball glove',
#  ' skateboard',
#  ' surfboard',
#  ' tennis racket',
#  ' bottle',
#  ' plate',
#  ' wine glass',
#  ' cup',
#  ' fork',
#  ' knife',
#  ' spoon',
#  ' bowl',
#  ' banana',
#  ' apple',
#  ' sandwich',
#  ' orange',
#  ' broccoli',
#  ' carrot',
#  ' hot dog',
#  ' pizza',
#  ' donut',
#  ' cake',
#  ' chair',
#  ' couch',
#  ' potted plant',
#  ' bed',
#  ' mirror',
#  ' dining table',
#  ' window',
#  ' desk',
#  ' toilet',
#  ' door',
#  ' tv',
#  ' laptop',
#  ' mouse',
#  ' remote',
#  ' keyboard',
#  ' cell phone',
#  ' microwave',
#  ' oven',
#  ' toaster',
#  ' sink',
#  ' refrigerator',
#  ' blender',
#  ' book',
#  ' clock',
#  ' vase',
#  ' scissors',
#  ' teddy bear',
#  ' hair drier',
#  ' toothbrush',
#  ' hair brush']

# %%
# color list for different classes
color_list=np.random.uniform(low=0,high=255,size=(len(class_list)))
print(len(class_list),len(color_list))
# Out:
# 92 92

# %%
#cache dir where all models willbe downloaded
models_dir= "pretrained_models"

os.makedirs(models_dir, exist_ok=True)

# %%
# https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md

model_URL="http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d0_coco17_tpu-32.tar.gz"
model_file=os.path.basename(model_URL)
print(model_file)
# Out:
# efficientdet_d0_coco17_tpu-32.tar.gz

# %%
#download model file
get_file(fname=model_file,origin=model_URL, cache_dir=models_dir, cache_subdir="checkpoints", extract=True)
# Out:
# Downloading data from http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d0_coco17_tpu-32.tar.gz
# 30744576/30736482 [==============================] - 13s 0us/step
# './pretrained_models\\checkpoints\\efficientdet_d0_coco17_tpu-32.tar.gz'

# %%
# load Model
model_name=model_file[:model_file.index('.')]
print(model_name)
tf.keras.backend.clear_session()
model=tf.saved_model.load(os.path.join(models_dir,"checkpoints",model_name,"saved_model"))

print("Model: "+ model_name+" loaded successfully")
# Out:
# efficientdet_d0_coco17_tpu-32
# WARNING:tensorflow:From C:\Users\Swami\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# WARNING:absl:Importing a function (__inference___call___32344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_EfficientDet-D0_layer_call_and_return_conditional_losses_97451) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_bifpn_layer_call_and_return_conditional_losses_77595) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_EfficientDet-D0_layer_call_and_return_conditional_losses_103456) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_EfficientDet-D0_layer_call_and_return_conditional_losses_93843) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_EfficientDet-D0_layer_call_and_return_conditional_losses_107064) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_bifpn_layer_call_and_return_conditional_losses_75975) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Model: efficientdet_d0_coco17_tpu-32 loaded successfully

# %%
 
#read test image
image_path= "test/image1.jpg"
image=cv2.imread(image_path)

# %%
# image to tensor conversion
image_np=cv2.cvtColor(image.copy(),cv2.COLOR_BGR2RGB) #converts the color format from BGR (used by OpenCV) to RGB (typically used by TensorFlow and other libraries).
image_tensor=tf.convert_to_tensor(image_np,dtype=tf.uint8) # converts the RGB image (now a NumPy array) into a TensorFlow tensor
image_tensor=image_tensor[tf.newaxis,...] # image_tensor will have a shape of (1, height, width, 3)

# %%
image_tensor
# Out:
# <tf.Tensor: shape=(1, 636, 1024, 3), dtype=uint8, numpy=
# array([[[[ 53,  39,  26],
#          [ 40,  26,  15],
#          [ 27,  13,   4],
#          ...,
#          [233, 221, 199],
#          [234, 222, 200],
#          [234, 222, 200]],
#
#         [[ 52,  38,  27],
#          [ 41,  27,  16],
#          [ 31,  17,   8],
#          ...,
#          [231, 219, 197],
#          [231, 219, 197],
#          [231, 219, 197]],
#
#         [[ 49,  37,  25],
#          [ 43,  29,  20],
#          [ 38,  24,  15],
#          ...,
#          [228, 216, 194],
#          [228, 216, 194],
#          [228, 216, 194]],
#
#         ...,
#
#         [[ 66,  65,  79],
#          [ 64,  63,  77],
#          [ 64,  63,  77],
#          ...,
#          [100, 102, 123],
#          [ 92,  96, 121],
#          [ 91,  97, 123]],
#
#         [[ 72,  72,  82],
#          [ 71,  71,  81],
#          [ 68,  68,  78],
#          ...,
#          [101, 103, 124],
#          [ 97, 101, 126],
#          [102, 108, 134]],
#
#         [[ 77,  78,  83],
#          [ 78,  79,  84],
#          [ 75,  76,  81],
#          ...,
#          [ 98, 100, 123],
#          [ 95,  99, 124],
#          [101, 107, 133]]]], dtype=uint8)>

# %%
detections = model(image_tensor) # runs the image_tensor through a trained model to generate predictions

# %%
detections
# Out:
# {'detection_boxes': <tf.Tensor: shape=(1, 100, 4), dtype=float32, numpy=
#  array([[[2.23913118e-02, 1.48446262e-02, 8.55852187e-01, 3.10046166e-01],
#          [1.80860162e-01, 3.90633434e-01, 9.13722336e-01, 9.75541234e-01],
#          [6.66696668e-01, 3.17782819e-01, 8.27371836e-01, 4.66989934e-01],
#          [0.00000000e+00, 7.65215933e-01, 6.99731350e-01, 1.00000000e+00],
#          [0.00000000e+00, 3.04474711e-01, 8.38686943e-01, 7.12805629e-01],
#          [3.00226733e-02, 3.21255565e-01, 8.10426772e-01, 7.29539990e-01],
#          [5.85378528e-01, 4.13841605e-01, 8.42679560e-01, 7.13512063e-01],
#          [0.00000000e+00, 7.59520173e-01, 7.11742282e-01, 1.00000000e+00],
#          [1.03309341e-01, 3.77020508e-01, 9.03490543e-01, 9.08252120e-01],
#          [1.63228977e-02, 0.00000000e+00, 4.50451136e-01, 3.03562135e-01],
#          [6.95664883e-01, 3.47331166e-01, 7.91592240e-01, 4.70526934e-01],
#          [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#          [6.58288181e-01, 5.89688480e-01, 8.15932214e-01, 7.13399827e-01],
#          [2.38223281e-02, 6.75581098e-01, 8.64110172e-01, 9.84525084e-01],
#          [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#          [8.01500282e-04, 7.00041592e-01, 1.02831252e-01, 7.95413196e-01],
#          [0.00000000e+00, 6.98974490e-01, 1.02367952e-01, 7.96361446e-01],
#          [1.87351868e-01, 3.63172770e-01, 8.95008147e-01, 9.72572923e-01],
#          [1.83409840e-01, 3.79014790e-01, 9.26739931e-01, 9.85134423e-01],
#          [3.05355713e-03, 4.93788540e-01, 2.54513681e-01, 6.99859679e-01],
#          [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#          [1.05180079e-04, 3.40287119e-01, 3.38058233e-01, 7.06232667e-01],
#          [7.02680051e-01, 5.94860911e-01, 8.13300550e-01, 6.77493572e-01],
#          [2.26097573e-02, 3.80294502e-01, 4.75173444e-01, 7.00514853e-01],
#          [1.92882940e-01, 3.87702852e-01, 9.47564244e-01, 9.71558094e-01],
#          [1.55639648e-03, 4.70294058e-02, 9.02123570e-01, 6.29451156e-01],
#          [2.23837309e-02, 3.11229855e-01, 6.74913466e-01, 5.33136547e-01],
#          [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#          [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#          [5.95236182e-01, 3.54388297e-01, 8.43976438e-01, 7.21730530e-01],
#          [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#          [1.44627644e-02, 1.43623352e-01, 5.45527518e-01, 6.90786719e-01],
#          [1.97332263e-01, 3.81854326e-01, 9.25759733e-01, 9.73080277e-01],
#          [1.83409840e-01, 3.79014790e-01, 9.26739931e-01, 9.85134423e-01],
#          [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#          [6.46501005e-01, 3.20025623e-01, 8.25530767e-01, 5.94906151e-01],
#          [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#          [2.05297619e-01, 3.91255587e-01, 9.14074004e-01, 9.82228041e-01],
#          [2.64059100e-02, 1.15096718e-02, 8.61630023e-01, 3.10377896e-01],
#          [5.19311056e-03, 4.06745076e-03, 3.95475328e-01, 1.89504057e-01],
#          [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#          [7.25537479e-01, 3.45576465e-01, 8.39610696e-01, 4.67468262e-01],
#          [2.31043734e-02, 2.57560313e-01, 5.81569791e-01, 7.02881157e-01],
#          [2.98319384e-02, 3.65958184e-01, 5.73660612e-01, 8.04165125e-01],
#          [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#          [1.69095069e-01, 4.92072940e-01, 8.83075833e-01, 9.83338594e-01],
#          [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#          [4.13318351e-02, 5.60269952e-01, 7.89581180e-01, 1.00000000e+00],
#          [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#          [5.84464729e-01, 3.43006551e-01, 9.04664397e-01, 7.30643570e-01],
#          [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#          [0.00000000e+00, 3.11725616e-01, 8.80813837e-01, 7.21094251e-01],
#          [2.12251738e-01, 2.86935419e-01, 4.31382060e-01, 3.40297967e-01],
#          [5.95236182e-01, 3.54388297e-01, 8.43976438e-01, 7.21730530e-01],
#          [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#          [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#          [0.00000000e+00, 6.95554316e-01, 1.02757633e-01, 7.96790183e-01],
#          [8.86785146e-03, 7.82358646e-03, 4.98353630e-01, 2.91892618e-01],
#          [1.84949231e-03, 4.23764050e-01, 2.80756325e-01, 7.00085223e-01],
#          [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#          [4.00631487e-01, 4.09532845e-01, 8.58500063e-01, 8.70768011e-01],
#          [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#          [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#          [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#          [1.31122898e-02, 3.20639342e-01, 8.48415136e-01, 7.52396107e-01],
#          [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#          [4.70037870e-02, 3.13641131e-03, 8.60032439e-01, 3.03909123e-01],
#          [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#          [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#          [0.00000000e+00, 1.11461431e-01, 1.10690638e-01, 2.81062633e-01],
#          [3.31917405e-01, 2.82527149e-01, 4.30843711e-01, 3.39805186e-01],
#          [1.37605723e-02, 1.08526349e-01, 7.63516366e-01, 8.21296632e-01],
#          [6.74584787e-03, 3.38532776e-03, 3.73343796e-01, 2.50643820e-01],
#          [6.74690068e-01, 5.15726328e-01, 8.08076918e-01, 6.98190331e-01],
#          [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#          [2.93113645e-02, 0.00000000e+00, 6.89612865e-01, 4.84505802e-01],
#          [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#          [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#          [6.65253937e-01, 3.18867505e-01, 8.05797040e-01, 4.70915973e-01],
#          [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#          [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#          [0.00000000e+00, 8.89614224e-03, 1.20146714e-01, 1.88193291e-01],
#          [8.62894114e-03, 3.03156376e-02, 5.57966232e-01, 5.97268105e-01],
#          [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#          [2.20783874e-01, 3.07564408e-01, 9.08765256e-01, 7.11970448e-01],
#          [2.64059100e-02, 1.15096718e-02, 8.61630023e-01, 3.10377896e-01],
#          [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#          [2.99196541e-02, 2.96772271e-03, 5.56466460e-01, 1.56388789e-01],
#          [0.00000000e+00, 1.18450522e-02, 1.39704064e-01, 2.85328537e-01],
#          [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#          [0.00000000e+00, 3.11725616e-01, 8.80813837e-01, 7.21094251e-01],
#          [1.63228977e-02, 0.00000000e+00, 4.50451136e-01, 3.03562135e-01],
#          [2.03049317e-01, 2.84194112e-01, 4.24217224e-01, 3.41155708e-01],
#          [6.82043612e-01, 6.01706386e-01, 7.51688540e-01, 6.83390737e-01],
#          [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#          [8.62894114e-03, 3.03156376e-02, 5.57966232e-01, 5.97268105e-01],
#          [6.62362218e-01, 3.16075414e-01, 8.21889102e-01, 4.68695253e-01],
#          [1.31122898e-02, 3.20639342e-01, 8.48415136e-01, 7.52396107e-01],
#          [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#          [1.55639648e-03, 4.70294058e-02, 9.02123570e-01, 6.29451156e-01]]],
#        dtype=float32)>,
#  'detection_scores': <tf.Tensor: shape=(1, 100), dtype=float32, numpy=
#  array([[0.8404553 , 0.6271829 , 0.47305855, 0.38983604, 0.3617795 ,
#          0.34211454, 0.22777662, 0.21836625, 0.20259193, 0.19431694,
#          0.17641121, 0.17597066, 0.166858  , 0.16553412, 0.16476406,
#          0.1600988 , 0.15856722, 0.15298282, 0.15218744, 0.15126096,
#          0.14983998, 0.14650044, 0.13032514, 0.12530741, 0.12367757,
#          0.12095757, 0.11862903, 0.11556328, 0.11438581, 0.11326766,
#          0.10742825, 0.10604662, 0.10541444, 0.10447384, 0.10078327,
#          0.09843926, 0.09672134, 0.09579492, 0.09299016, 0.08992459,
#          0.08932109, 0.08724906, 0.0869742 , 0.0868568 , 0.08680961,
#          0.085035  , 0.08445096, 0.08231018, 0.08166456, 0.0814077 ,
#          0.08092276, 0.08030824, 0.08006994, 0.07963908, 0.0792805 ,
#          0.07761956, 0.07746154, 0.07727689, 0.07690878, 0.07685439,
#          0.07625259, 0.07622874, 0.07588945, 0.07567362, 0.07318679,
#          0.07317931, 0.07200006, 0.0715774 , 0.07123972, 0.07016946,
#          0.06977452, 0.06974751, 0.06959371, 0.06953295, 0.06898179,
#          0.0680158 , 0.06774523, 0.06754464, 0.06747988, 0.06633605,
#          0.06632902, 0.06631756, 0.06624954, 0.06620101, 0.06606686,
#          0.06606425, 0.06527372, 0.06487402, 0.06483031, 0.06469564,
#          0.06448712, 0.06392793, 0.06379383, 0.06322134, 0.06311081,
#          0.06232323, 0.06173305, 0.06074274, 0.06072097, 0.06049323]],
#        dtype=float32)>,
#  'raw_detection_scores': <tf.Tensor: shape=(1, 49104, 90), dtype=float32, numpy=
#  array([[[0.04100303, 0.00946472, 0.01386562, ..., 0.02861413,
#           0.00425427, 0.00804224],
#          [0.00291613, 0.00086771, 0.00101175, ..., 0.0027701 ,
#           0.00085935, 0.00076493],
#          [0.00049733, 0.00014628, 0.00011206, ..., 0.00036929,
#           0.00037182, 0.00013152],
#          ...,
#          [0.00561103, 0.00186337, 0.00194256, ..., 0.00445797,
#           0.00245701, 0.00252305],
#          [0.00695022, 0.00223879, 0.00238393, ..., 0.00462582,
#           0.00230709, 0.00212835],
#          [0.00827643, 0.0020346 , 0.00242739, ..., 0.00403782,
#           0.00189027, 0.00182221]]], dtype=float32)>,
#  'detection_anchor_indices': <tf.Tensor: shape=(1, 100), dtype=float32, numpy=
#  array([[46682., 48573., 41004., 46501., 46727., 48492., 41069., 46636.,
#          48564., 46243., 16951., 48471., 17066., 46925., 46970.,  1003.,
#           1579., 48585., 48568., 37625., 46970., 46299., 17641., 46449.,
#          48648., 48547., 46572., 48471., 46970., 41054., 47169., 46418.,
#          47039., 48568., 46874., 41026., 46933., 47048., 46394., 38036.,
#          46933., 18094., 46427., 46463., 47169., 46919., 46883., 48510.,
#          46781., 47155., 46970., 46865.,  7675., 41054., 47018., 46874.,
#           1570., 46378., 37895., 46781., 47038., 47018., 46874., 46781.,
#          46730., 47169., 48528., 46933., 47172.,  1265.,  8811., 48487.,
#          37757., 17051., 47172., 48468., 46970., 46883., 16349., 46883.,
#          47169., 37173., 46409., 46883., 47009., 46394., 47169., 38618.,
#          37201., 48471., 46865., 46243.,  6524., 16491., 47172., 46409.,
#          40998., 46730., 47018., 48547.]], dtype=float32)>,
#  'raw_detection_boxes': <tf.Tensor: shape=(1, 49104, 4), dtype=float32, numpy=
#  array([[[ 0.19294986,  0.36668742,  0.3034044 ,  0.36668742],
#          [ 0.02365241,  0.03686055,  0.05923988,  0.04926138],
#          [-0.00233841, -0.01041991,  0.07909818,  0.04448351],
#          ...,
#          [ 0.28769857,  0.51933914,  1.4700518 ,  1.1410999 ],
#          [ 0.1996612 ,  0.42462274,  1.6615369 ,  1.1429312 ],
#          [-0.12048876,  0.22969082,  1.8532467 ,  1.2285033 ]]],
#        dtype=float32)>,
#  'detection_classes': <tf.Tensor: shape=(1, 100), dtype=float32, numpy=
#  array([[18., 18., 51., 63.,  1., 18., 51., 62.,  1., 18., 51.,  1., 51.,
#          18., 21., 17., 18., 63., 15.,  1., 20.,  1., 51., 18., 21., 18.,
#           1., 88., 19., 79., 64.,  1., 20., 19., 62., 51.,  1., 17., 15.,
#           1., 17., 51., 63.,  1., 20., 62.,  3., 63., 33., 67., 23., 17.,
#          49., 81.,  1., 88.,  1.,  1., 18., 15., 18., 64., 16., 65., 15.,
#          70., 16., 21., 52., 31., 49., 63., 62., 51., 55., 18., 17., 65.,
#          50., 33., 86., 18., 15.,  4., 67., 62., 15., 18., 31., 63., 70.,
#          15., 67., 51., 61., 63., 52., 19., 79.,  1.]], dtype=float32)>,
#  'num_detections': <tf.Tensor: shape=(1,), dtype=float32, numpy=array([100.], dtype=float32)>,
#  'detection_multiclass_scores': <tf.Tensor: shape=(1, 100, 90), dtype=float32, numpy=
#  array([[[2.68006455e-02, 2.29850900e-03, 9.56728961e-03, ...,
#           3.35717127e-02, 1.83714292e-04, 1.19618635e-04],
#          [6.62108585e-02, 4.64346260e-03, 2.29698122e-02, ...,
#           2.60610264e-02, 5.66634350e-04, 3.70898400e-04],
#          [1.81715447e-03, 5.25023742e-03, 2.40424182e-03, ...,
#           4.19617165e-04, 1.07228674e-03, 1.08324655e-03],
#          ...,
#          [2.40005732e-01, 2.44680922e-02, 4.43018079e-02, ...,
#           4.77094054e-02, 4.68168641e-03, 4.07886598e-03],
#          [7.92804956e-02, 4.86845821e-02, 3.76107655e-02, ...,
#           2.60977242e-02, 7.62422523e-03, 5.51288808e-03],
#          [6.04932345e-02, 3.42746591e-03, 1.05337566e-02, ...,
#           1.54681941e-02, 6.23074302e-04, 7.00507313e-04]]], dtype=float32)>}

# %%
detections.keys()
# Out:
# dict_keys(['detection_boxes', 'detection_scores', 'raw_detection_scores', 'detection_anchor_indices', 'raw_detection_boxes', 'detection_classes', 'num_detections', 'detection_multiclass_scores'])

# %%
detections['detection_boxes']
# Out:
# <tf.Tensor: shape=(1, 100, 4), dtype=float32, numpy=
# array([[[2.23913118e-02, 1.48446262e-02, 8.55852187e-01, 3.10046166e-01],
#         [1.80860162e-01, 3.90633434e-01, 9.13722336e-01, 9.75541234e-01],
#         [6.66696668e-01, 3.17782819e-01, 8.27371836e-01, 4.66989934e-01],
#         [0.00000000e+00, 7.65215933e-01, 6.99731350e-01, 1.00000000e+00],
#         [0.00000000e+00, 3.04474711e-01, 8.38686943e-01, 7.12805629e-01],
#         [3.00226733e-02, 3.21255565e-01, 8.10426772e-01, 7.29539990e-01],
#         [5.85378528e-01, 4.13841605e-01, 8.42679560e-01, 7.13512063e-01],
#         [0.00000000e+00, 7.59520173e-01, 7.11742282e-01, 1.00000000e+00],
#         [1.03309341e-01, 3.77020508e-01, 9.03490543e-01, 9.08252120e-01],
#         [1.63228977e-02, 0.00000000e+00, 4.50451136e-01, 3.03562135e-01],
#         [6.95664883e-01, 3.47331166e-01, 7.91592240e-01, 4.70526934e-01],
#         [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#         [6.58288181e-01, 5.89688480e-01, 8.15932214e-01, 7.13399827e-01],
#         [2.38223281e-02, 6.75581098e-01, 8.64110172e-01, 9.84525084e-01],
#         [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#         [8.01500282e-04, 7.00041592e-01, 1.02831252e-01, 7.95413196e-01],
#         [0.00000000e+00, 6.98974490e-01, 1.02367952e-01, 7.96361446e-01],
#         [1.87351868e-01, 3.63172770e-01, 8.95008147e-01, 9.72572923e-01],
#         [1.83409840e-01, 3.79014790e-01, 9.26739931e-01, 9.85134423e-01],
#         [3.05355713e-03, 4.93788540e-01, 2.54513681e-01, 6.99859679e-01],
#         [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#         [1.05180079e-04, 3.40287119e-01, 3.38058233e-01, 7.06232667e-01],
#         [7.02680051e-01, 5.94860911e-01, 8.13300550e-01, 6.77493572e-01],
#         [2.26097573e-02, 3.80294502e-01, 4.75173444e-01, 7.00514853e-01],
#         [1.92882940e-01, 3.87702852e-01, 9.47564244e-01, 9.71558094e-01],
#         [1.55639648e-03, 4.70294058e-02, 9.02123570e-01, 6.29451156e-01],
#         [2.23837309e-02, 3.11229855e-01, 6.74913466e-01, 5.33136547e-01],
#         [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#         [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#         [5.95236182e-01, 3.54388297e-01, 8.43976438e-01, 7.21730530e-01],
#         [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#         [1.44627644e-02, 1.43623352e-01, 5.45527518e-01, 6.90786719e-01],
#         [1.97332263e-01, 3.81854326e-01, 9.25759733e-01, 9.73080277e-01],
#         [1.83409840e-01, 3.79014790e-01, 9.26739931e-01, 9.85134423e-01],
#         [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#         [6.46501005e-01, 3.20025623e-01, 8.25530767e-01, 5.94906151e-01],
#         [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#         [2.05297619e-01, 3.91255587e-01, 9.14074004e-01, 9.82228041e-01],
#         [2.64059100e-02, 1.15096718e-02, 8.61630023e-01, 3.10377896e-01],
#         [5.19311056e-03, 4.06745076e-03, 3.95475328e-01, 1.89504057e-01],
#         [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#         [7.25537479e-01, 3.45576465e-01, 8.39610696e-01, 4.67468262e-01],
#         [2.31043734e-02, 2.57560313e-01, 5.81569791e-01, 7.02881157e-01],
#         [2.98319384e-02, 3.65958184e-01, 5.73660612e-01, 8.04165125e-01],
#         [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#         [1.69095069e-01, 4.92072940e-01, 8.83075833e-01, 9.83338594e-01],
#         [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#         [4.13318351e-02, 5.60269952e-01, 7.89581180e-01, 1.00000000e+00],
#         [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#         [5.84464729e-01, 3.43006551e-01, 9.04664397e-01, 7.30643570e-01],
#         [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#         [0.00000000e+00, 3.11725616e-01, 8.80813837e-01, 7.21094251e-01],
#         [2.12251738e-01, 2.86935419e-01, 4.31382060e-01, 3.40297967e-01],
#         [5.95236182e-01, 3.54388297e-01, 8.43976438e-01, 7.21730530e-01],
#         [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#         [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#         [0.00000000e+00, 6.95554316e-01, 1.02757633e-01, 7.96790183e-01],
#         [8.86785146e-03, 7.82358646e-03, 4.98353630e-01, 2.91892618e-01],
#         [1.84949231e-03, 4.23764050e-01, 2.80756325e-01, 7.00085223e-01],
#         [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#         [4.00631487e-01, 4.09532845e-01, 8.58500063e-01, 8.70768011e-01],
#         [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#         [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#         [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#         [1.31122898e-02, 3.20639342e-01, 8.48415136e-01, 7.52396107e-01],
#         [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#         [4.70037870e-02, 3.13641131e-03, 8.60032439e-01, 3.03909123e-01],
#         [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#         [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#         [0.00000000e+00, 1.11461431e-01, 1.10690638e-01, 2.81062633e-01],
#         [3.31917405e-01, 2.82527149e-01, 4.30843711e-01, 3.39805186e-01],
#         [1.37605723e-02, 1.08526349e-01, 7.63516366e-01, 8.21296632e-01],
#         [6.74584787e-03, 3.38532776e-03, 3.73343796e-01, 2.50643820e-01],
#         [6.74690068e-01, 5.15726328e-01, 8.08076918e-01, 6.98190331e-01],
#         [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#         [2.93113645e-02, 0.00000000e+00, 6.89612865e-01, 4.84505802e-01],
#         [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#         [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#         [6.65253937e-01, 3.18867505e-01, 8.05797040e-01, 4.70915973e-01],
#         [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#         [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#         [0.00000000e+00, 8.89614224e-03, 1.20146714e-01, 1.88193291e-01],
#         [8.62894114e-03, 3.03156376e-02, 5.57966232e-01, 5.97268105e-01],
#         [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#         [2.20783874e-01, 3.07564408e-01, 9.08765256e-01, 7.11970448e-01],
#         [2.64059100e-02, 1.15096718e-02, 8.61630023e-01, 3.10377896e-01],
#         [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#         [2.99196541e-02, 2.96772271e-03, 5.56466460e-01, 1.56388789e-01],
#         [0.00000000e+00, 1.18450522e-02, 1.39704064e-01, 2.85328537e-01],
#         [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#         [0.00000000e+00, 3.11725616e-01, 8.80813837e-01, 7.21094251e-01],
#         [1.63228977e-02, 0.00000000e+00, 4.50451136e-01, 3.03562135e-01],
#         [2.03049317e-01, 2.84194112e-01, 4.24217224e-01, 3.41155708e-01],
#         [6.82043612e-01, 6.01706386e-01, 7.51688540e-01, 6.83390737e-01],
#         [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#         [8.62894114e-03, 3.03156376e-02, 5.57966232e-01, 5.97268105e-01],
#         [6.62362218e-01, 3.16075414e-01, 8.21889102e-01, 4.68695253e-01],
#         [1.31122898e-02, 3.20639342e-01, 8.48415136e-01, 7.52396107e-01],
#         [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#         [1.55639648e-03, 4.70294058e-02, 9.02123570e-01, 6.29451156e-01]]],
#       dtype=float32)>

# %%
detections['detection_boxes'][0]
# Out:
# <tf.Tensor: shape=(100, 4), dtype=float32, numpy=
# array([[2.23913118e-02, 1.48446262e-02, 8.55852187e-01, 3.10046166e-01],
#        [1.80860162e-01, 3.90633434e-01, 9.13722336e-01, 9.75541234e-01],
#        [6.66696668e-01, 3.17782819e-01, 8.27371836e-01, 4.66989934e-01],
#        [0.00000000e+00, 7.65215933e-01, 6.99731350e-01, 1.00000000e+00],
#        [0.00000000e+00, 3.04474711e-01, 8.38686943e-01, 7.12805629e-01],
#        [3.00226733e-02, 3.21255565e-01, 8.10426772e-01, 7.29539990e-01],
#        [5.85378528e-01, 4.13841605e-01, 8.42679560e-01, 7.13512063e-01],
#        [0.00000000e+00, 7.59520173e-01, 7.11742282e-01, 1.00000000e+00],
#        [1.03309341e-01, 3.77020508e-01, 9.03490543e-01, 9.08252120e-01],
#        [1.63228977e-02, 0.00000000e+00, 4.50451136e-01, 3.03562135e-01],
#        [6.95664883e-01, 3.47331166e-01, 7.91592240e-01, 4.70526934e-01],
#        [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#        [6.58288181e-01, 5.89688480e-01, 8.15932214e-01, 7.13399827e-01],
#        [2.38223281e-02, 6.75581098e-01, 8.64110172e-01, 9.84525084e-01],
#        [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#        [8.01500282e-04, 7.00041592e-01, 1.02831252e-01, 7.95413196e-01],
#        [0.00000000e+00, 6.98974490e-01, 1.02367952e-01, 7.96361446e-01],
#        [1.87351868e-01, 3.63172770e-01, 8.95008147e-01, 9.72572923e-01],
#        [1.83409840e-01, 3.79014790e-01, 9.26739931e-01, 9.85134423e-01],
#        [3.05355713e-03, 4.93788540e-01, 2.54513681e-01, 6.99859679e-01],
#        [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#        [1.05180079e-04, 3.40287119e-01, 3.38058233e-01, 7.06232667e-01],
#        [7.02680051e-01, 5.94860911e-01, 8.13300550e-01, 6.77493572e-01],
#        [2.26097573e-02, 3.80294502e-01, 4.75173444e-01, 7.00514853e-01],
#        [1.92882940e-01, 3.87702852e-01, 9.47564244e-01, 9.71558094e-01],
#        [1.55639648e-03, 4.70294058e-02, 9.02123570e-01, 6.29451156e-01],
#        [2.23837309e-02, 3.11229855e-01, 6.74913466e-01, 5.33136547e-01],
#        [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#        [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#        [5.95236182e-01, 3.54388297e-01, 8.43976438e-01, 7.21730530e-01],
#        [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#        [1.44627644e-02, 1.43623352e-01, 5.45527518e-01, 6.90786719e-01],
#        [1.97332263e-01, 3.81854326e-01, 9.25759733e-01, 9.73080277e-01],
#        [1.83409840e-01, 3.79014790e-01, 9.26739931e-01, 9.85134423e-01],
#        [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#        [6.46501005e-01, 3.20025623e-01, 8.25530767e-01, 5.94906151e-01],
#        [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#        [2.05297619e-01, 3.91255587e-01, 9.14074004e-01, 9.82228041e-01],
#        [2.64059100e-02, 1.15096718e-02, 8.61630023e-01, 3.10377896e-01],
#        [5.19311056e-03, 4.06745076e-03, 3.95475328e-01, 1.89504057e-01],
#        [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#        [7.25537479e-01, 3.45576465e-01, 8.39610696e-01, 4.67468262e-01],
#        [2.31043734e-02, 2.57560313e-01, 5.81569791e-01, 7.02881157e-01],
#        [2.98319384e-02, 3.65958184e-01, 5.73660612e-01, 8.04165125e-01],
#        [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#        [1.69095069e-01, 4.92072940e-01, 8.83075833e-01, 9.83338594e-01],
#        [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#        [4.13318351e-02, 5.60269952e-01, 7.89581180e-01, 1.00000000e+00],
#        [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#        [5.84464729e-01, 3.43006551e-01, 9.04664397e-01, 7.30643570e-01],
#        [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#        [0.00000000e+00, 3.11725616e-01, 8.80813837e-01, 7.21094251e-01],
#        [2.12251738e-01, 2.86935419e-01, 4.31382060e-01, 3.40297967e-01],
#        [5.95236182e-01, 3.54388297e-01, 8.43976438e-01, 7.21730530e-01],
#        [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#        [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#        [0.00000000e+00, 6.95554316e-01, 1.02757633e-01, 7.96790183e-01],
#        [8.86785146e-03, 7.82358646e-03, 4.98353630e-01, 2.91892618e-01],
#        [1.84949231e-03, 4.23764050e-01, 2.80756325e-01, 7.00085223e-01],
#        [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#        [4.00631487e-01, 4.09532845e-01, 8.58500063e-01, 8.70768011e-01],
#        [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#        [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#        [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#        [1.31122898e-02, 3.20639342e-01, 8.48415136e-01, 7.52396107e-01],
#        [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#        [4.70037870e-02, 3.13641131e-03, 8.60032439e-01, 3.03909123e-01],
#        [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#        [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#        [0.00000000e+00, 1.11461431e-01, 1.10690638e-01, 2.81062633e-01],
#        [3.31917405e-01, 2.82527149e-01, 4.30843711e-01, 3.39805186e-01],
#        [1.37605723e-02, 1.08526349e-01, 7.63516366e-01, 8.21296632e-01],
#        [6.74584787e-03, 3.38532776e-03, 3.73343796e-01, 2.50643820e-01],
#        [6.74690068e-01, 5.15726328e-01, 8.08076918e-01, 6.98190331e-01],
#        [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#        [2.93113645e-02, 0.00000000e+00, 6.89612865e-01, 4.84505802e-01],
#        [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#        [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#        [6.65253937e-01, 3.18867505e-01, 8.05797040e-01, 4.70915973e-01],
#        [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#        [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#        [0.00000000e+00, 8.89614224e-03, 1.20146714e-01, 1.88193291e-01],
#        [8.62894114e-03, 3.03156376e-02, 5.57966232e-01, 5.97268105e-01],
#        [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#        [2.20783874e-01, 3.07564408e-01, 9.08765256e-01, 7.11970448e-01],
#        [2.64059100e-02, 1.15096718e-02, 8.61630023e-01, 3.10377896e-01],
#        [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#        [2.99196541e-02, 2.96772271e-03, 5.56466460e-01, 1.56388789e-01],
#        [0.00000000e+00, 1.18450522e-02, 1.39704064e-01, 2.85328537e-01],
#        [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#        [0.00000000e+00, 3.11725616e-01, 8.80813837e-01, 7.21094251e-01],
#        [1.63228977e-02, 0.00000000e+00, 4.50451136e-01, 3.03562135e-01],
#        [2.03049317e-01, 2.84194112e-01, 4.24217224e-01, 3.41155708e-01],
#        [6.82043612e-01, 6.01706386e-01, 7.51688540e-01, 6.83390737e-01],
#        [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#        [8.62894114e-03, 3.03156376e-02, 5.57966232e-01, 5.97268105e-01],
#        [6.62362218e-01, 3.16075414e-01, 8.21889102e-01, 4.68695253e-01],
#        [1.31122898e-02, 3.20639342e-01, 8.48415136e-01, 7.52396107e-01],
#        [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#        [1.55639648e-03, 4.70294058e-02, 9.02123570e-01, 6.29451156e-01]],
#       dtype=float32)>

# %%
type(detections['detection_boxes'][0])
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
bboxs=detections['detection_boxes'][0].numpy()
bboxs
# Out:
# array([[2.23913118e-02, 1.48446262e-02, 8.55852187e-01, 3.10046166e-01],
#        [1.80860162e-01, 3.90633434e-01, 9.13722336e-01, 9.75541234e-01],
#        [6.66696668e-01, 3.17782819e-01, 8.27371836e-01, 4.66989934e-01],
#        [0.00000000e+00, 7.65215933e-01, 6.99731350e-01, 1.00000000e+00],
#        [0.00000000e+00, 3.04474711e-01, 8.38686943e-01, 7.12805629e-01],
#        [3.00226733e-02, 3.21255565e-01, 8.10426772e-01, 7.29539990e-01],
#        [5.85378528e-01, 4.13841605e-01, 8.42679560e-01, 7.13512063e-01],
#        [0.00000000e+00, 7.59520173e-01, 7.11742282e-01, 1.00000000e+00],
#        [1.03309341e-01, 3.77020508e-01, 9.03490543e-01, 9.08252120e-01],
#        [1.63228977e-02, 0.00000000e+00, 4.50451136e-01, 3.03562135e-01],
#        [6.95664883e-01, 3.47331166e-01, 7.91592240e-01, 4.70526934e-01],
#        [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#        [6.58288181e-01, 5.89688480e-01, 8.15932214e-01, 7.13399827e-01],
#        [2.38223281e-02, 6.75581098e-01, 8.64110172e-01, 9.84525084e-01],
#        [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#        [8.01500282e-04, 7.00041592e-01, 1.02831252e-01, 7.95413196e-01],
#        [0.00000000e+00, 6.98974490e-01, 1.02367952e-01, 7.96361446e-01],
#        [1.87351868e-01, 3.63172770e-01, 8.95008147e-01, 9.72572923e-01],
#        [1.83409840e-01, 3.79014790e-01, 9.26739931e-01, 9.85134423e-01],
#        [3.05355713e-03, 4.93788540e-01, 2.54513681e-01, 6.99859679e-01],
#        [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#        [1.05180079e-04, 3.40287119e-01, 3.38058233e-01, 7.06232667e-01],
#        [7.02680051e-01, 5.94860911e-01, 8.13300550e-01, 6.77493572e-01],
#        [2.26097573e-02, 3.80294502e-01, 4.75173444e-01, 7.00514853e-01],
#        [1.92882940e-01, 3.87702852e-01, 9.47564244e-01, 9.71558094e-01],
#        [1.55639648e-03, 4.70294058e-02, 9.02123570e-01, 6.29451156e-01],
#        [2.23837309e-02, 3.11229855e-01, 6.74913466e-01, 5.33136547e-01],
#        [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#        [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#        [5.95236182e-01, 3.54388297e-01, 8.43976438e-01, 7.21730530e-01],
#        [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#        [1.44627644e-02, 1.43623352e-01, 5.45527518e-01, 6.90786719e-01],
#        [1.97332263e-01, 3.81854326e-01, 9.25759733e-01, 9.73080277e-01],
#        [1.83409840e-01, 3.79014790e-01, 9.26739931e-01, 9.85134423e-01],
#        [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#        [6.46501005e-01, 3.20025623e-01, 8.25530767e-01, 5.94906151e-01],
#        [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#        [2.05297619e-01, 3.91255587e-01, 9.14074004e-01, 9.82228041e-01],
#        [2.64059100e-02, 1.15096718e-02, 8.61630023e-01, 3.10377896e-01],
#        [5.19311056e-03, 4.06745076e-03, 3.95475328e-01, 1.89504057e-01],
#        [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#        [7.25537479e-01, 3.45576465e-01, 8.39610696e-01, 4.67468262e-01],
#        [2.31043734e-02, 2.57560313e-01, 5.81569791e-01, 7.02881157e-01],
#        [2.98319384e-02, 3.65958184e-01, 5.73660612e-01, 8.04165125e-01],
#        [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#        [1.69095069e-01, 4.92072940e-01, 8.83075833e-01, 9.83338594e-01],
#        [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#        [4.13318351e-02, 5.60269952e-01, 7.89581180e-01, 1.00000000e+00],
#        [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#        [5.84464729e-01, 3.43006551e-01, 9.04664397e-01, 7.30643570e-01],
#        [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#        [0.00000000e+00, 3.11725616e-01, 8.80813837e-01, 7.21094251e-01],
#        [2.12251738e-01, 2.86935419e-01, 4.31382060e-01, 3.40297967e-01],
#        [5.95236182e-01, 3.54388297e-01, 8.43976438e-01, 7.21730530e-01],
#        [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#        [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#        [0.00000000e+00, 6.95554316e-01, 1.02757633e-01, 7.96790183e-01],
#        [8.86785146e-03, 7.82358646e-03, 4.98353630e-01, 2.91892618e-01],
#        [1.84949231e-03, 4.23764050e-01, 2.80756325e-01, 7.00085223e-01],
#        [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#        [4.00631487e-01, 4.09532845e-01, 8.58500063e-01, 8.70768011e-01],
#        [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#        [7.50079798e-03, 3.42344224e-01, 8.74632239e-01, 8.17127764e-01],
#        [9.93738230e-03, 7.53752351e-01, 7.89119065e-01, 1.00000000e+00],
#        [1.31122898e-02, 3.20639342e-01, 8.48415136e-01, 7.52396107e-01],
#        [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#        [4.70037870e-02, 3.13641131e-03, 8.60032439e-01, 3.03909123e-01],
#        [7.39979278e-03, 7.65252471e-01, 7.87526250e-01, 1.00000000e+00],
#        [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#        [0.00000000e+00, 1.11461431e-01, 1.10690638e-01, 2.81062633e-01],
#        [3.31917405e-01, 2.82527149e-01, 4.30843711e-01, 3.39805186e-01],
#        [1.37605723e-02, 1.08526349e-01, 7.63516366e-01, 8.21296632e-01],
#        [6.74584787e-03, 3.38532776e-03, 3.73343796e-01, 2.50643820e-01],
#        [6.74690068e-01, 5.15726328e-01, 8.08076918e-01, 6.98190331e-01],
#        [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#        [2.93113645e-02, 0.00000000e+00, 6.89612865e-01, 4.84505802e-01],
#        [5.42240739e-02, 1.81143135e-02, 8.59341979e-01, 3.07261050e-01],
#        [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#        [6.65253937e-01, 3.18867505e-01, 8.05797040e-01, 4.70915973e-01],
#        [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#        [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#        [0.00000000e+00, 8.89614224e-03, 1.20146714e-01, 1.88193291e-01],
#        [8.62894114e-03, 3.03156376e-02, 5.57966232e-01, 5.97268105e-01],
#        [1.31741256e-01, 3.69374454e-01, 9.03464258e-01, 9.34542239e-01],
#        [2.20783874e-01, 3.07564408e-01, 9.08765256e-01, 7.11970448e-01],
#        [2.64059100e-02, 1.15096718e-02, 8.61630023e-01, 3.10377896e-01],
#        [5.80826998e-01, 3.84021401e-01, 9.04424667e-01, 7.12446332e-01],
#        [2.99196541e-02, 2.96772271e-03, 5.56466460e-01, 1.56388789e-01],
#        [0.00000000e+00, 1.18450522e-02, 1.39704064e-01, 2.85328537e-01],
#        [5.41779585e-02, 5.78419864e-03, 8.73236120e-01, 3.19961369e-01],
#        [0.00000000e+00, 3.11725616e-01, 8.80813837e-01, 7.21094251e-01],
#        [1.63228977e-02, 0.00000000e+00, 4.50451136e-01, 3.03562135e-01],
#        [2.03049317e-01, 2.84194112e-01, 4.24217224e-01, 3.41155708e-01],
#        [6.82043612e-01, 6.01706386e-01, 7.51688540e-01, 6.83390737e-01],
#        [5.91927826e-01, 3.75263035e-01, 8.92181337e-01, 6.99265182e-01],
#        [8.62894114e-03, 3.03156376e-02, 5.57966232e-01, 5.97268105e-01],
#        [6.62362218e-01, 3.16075414e-01, 8.21889102e-01, 4.68695253e-01],
#        [1.31122898e-02, 3.20639342e-01, 8.48415136e-01, 7.52396107e-01],
#        [3.16098660e-01, 3.43112499e-01, 9.26564872e-01, 7.57003188e-01],
#        [1.55639648e-03, 4.70294058e-02, 9.02123570e-01, 6.29451156e-01]],
#       dtype=float32)

# %%
detections['detection_classes'][0]
# Out:
# <tf.Tensor: shape=(100,), dtype=float32, numpy=
# array([18., 18., 51., 63.,  1., 18., 51., 62.,  1., 18., 51.,  1., 51.,
#        18., 21., 17., 18., 63., 15.,  1., 20.,  1., 51., 18., 21., 18.,
#         1., 88., 19., 79., 64.,  1., 20., 19., 62., 51.,  1., 17., 15.,
#         1., 17., 51., 63.,  1., 20., 62.,  3., 63., 33., 67., 23., 17.,
#        49., 81.,  1., 88.,  1.,  1., 18., 15., 18., 64., 16., 65., 15.,
#        70., 16., 21., 52., 31., 49., 63., 62., 51., 55., 18., 17., 65.,
#        50., 33., 86., 18., 15.,  4., 67., 62., 15., 18., 31., 63., 70.,
#        15., 67., 51., 61., 63., 52., 19., 79.,  1.], dtype=float32)>

# %%
class_indexes=detections['detection_classes'][0].numpy().astype(np.int32)
class_indexes
# Out:
# array([18, 18, 51, 63,  1, 18, 51, 62,  1, 18, 51,  1, 51, 18, 21, 17, 18,
#        63, 15,  1, 20,  1, 51, 18, 21, 18,  1, 88, 19, 79, 64,  1, 20, 19,
#        62, 51,  1, 17, 15,  1, 17, 51, 63,  1, 20, 62,  3, 63, 33, 67, 23,
#        17, 49, 81,  1, 88,  1,  1, 18, 15, 18, 64, 16, 65, 15, 70, 16, 21,
#        52, 31, 49, 63, 62, 51, 55, 18, 17, 65, 50, 33, 86, 18, 15,  4, 67,
#        62, 15, 18, 31, 63, 70, 15, 67, 51, 61, 63, 52, 19, 79,  1])

# %%
class_scores=detections['detection_scores'][0].numpy()
class_scores
# Out:
# array([0.8404553 , 0.6271829 , 0.47305855, 0.38983604, 0.3617795 ,
#        0.34211454, 0.22777662, 0.21836625, 0.20259193, 0.19431694,
#        0.17641121, 0.17597066, 0.166858  , 0.16553412, 0.16476406,
#        0.1600988 , 0.15856722, 0.15298282, 0.15218744, 0.15126096,
#        0.14983998, 0.14650044, 0.13032514, 0.12530741, 0.12367757,
#        0.12095757, 0.11862903, 0.11556328, 0.11438581, 0.11326766,
#        0.10742825, 0.10604662, 0.10541444, 0.10447384, 0.10078327,
#        0.09843926, 0.09672134, 0.09579492, 0.09299016, 0.08992459,
#        0.08932109, 0.08724906, 0.0869742 , 0.0868568 , 0.08680961,
#        0.085035  , 0.08445096, 0.08231018, 0.08166456, 0.0814077 ,
#        0.08092276, 0.08030824, 0.08006994, 0.07963908, 0.0792805 ,
#        0.07761956, 0.07746154, 0.07727689, 0.07690878, 0.07685439,
#        0.07625259, 0.07622874, 0.07588945, 0.07567362, 0.07318679,
#        0.07317931, 0.07200006, 0.0715774 , 0.07123972, 0.07016946,
#        0.06977452, 0.06974751, 0.06959371, 0.06953295, 0.06898179,
#        0.0680158 , 0.06774523, 0.06754464, 0.06747988, 0.06633605,
#        0.06632902, 0.06631756, 0.06624954, 0.06620101, 0.06606686,
#        0.06606425, 0.06527372, 0.06487402, 0.06483031, 0.06469564,
#        0.06448712, 0.06392793, 0.06379383, 0.06322134, 0.06311081,
#        0.06232323, 0.06173305, 0.06074274, 0.06072097, 0.06049323],
#       dtype=float32)

# %%
iH,iW,iC=image.shape

# %%
iH,iW,iC
# Out:
# (636, 1024, 3)

# %%
# bounding box
#if bbox is found i.e. object is detected
if len(bboxs)!=0:
    for i in range(0,len(bboxs)):
        bbox=tuple(bboxs[i].tolist())
        class_confidence=round(100*class_scores[i])
        class_index=class_indexes[i]
        
        if class_confidence>50.0:            
            print("class_confidence--",class_confidence)
            class_lbl_txt=class_list[class_index]
            class_color=color_list[class_index]

            display_text=str(class_lbl_txt)+" "+str(class_confidence)

            #get values of bbox
            #below values are normalised x,y cordinates, 
            #Normalized x, y coordinates refer to coordinates that are scaled to fit within a fixed range, typically [0,1], rather than using the original pixel values. 
            ymin,xmin,ymax,xmax=bbox
            #converting them to actual x,y values
            xmin,xmax,ymin,ymax=(xmin*iW,xmax*iW,ymin*iH,ymax*iH)
            #converting flaot to int
            xmin,xmax,ymin,ymax=int(xmin),int(xmax),int(ymin),int(ymax)

            cv2.rectangle(image,(xmin,ymin),(xmax,ymax), color=class_color,thickness=2)
            cv2.putText(image,display_text,(xmin,ymin+10),cv2.FONT_HERSHEY_PLAIN,1,class_color,2)

    #cv2.imshow("result",image)
    cv2.imwrite(model_name+".jpg",image)
# Out:
# class_confidence-- 84
# class_confidence-- 63

# %%
display_text
# Out:
# ' dog 63'

# %%
# Object detection in Video 
def createBoundingBox(image):
    image_np=cv2.cvtColor(image.copy(),cv2.COLOR_BGR2RGB)
    image_tensor=tf.convert_to_tensor(image_np,dtype=tf.uint8)
    image_tensor=image_tensor[tf.newaxis,...]
    detections=model(image_tensor)
    bboxs=detections['detection_boxes'][0].numpy()
    class_indexes=detections['detection_classes'][0].numpy().astype(np.int32)
    class_scores=detections['detection_scores'][0].numpy()
    iH,iW,iC=image.shape
    if len(bboxs)!=0:
        for i in range(0,len(bboxs)):
            bbox=tuple(bboxs[i].tolist())
            class_confidence=round(100*class_scores[i])
            class_index=class_indexes[i]
            
            if class_confidence>50.0:            
                print("class_confidence--",class_confidence)
                class_lbl_txt=class_list[class_index]
                class_color=color_list[class_index]
    
                display_text=str(class_lbl_txt)+" "+str(class_confidence)
    
                #get values of bbox
                #below values are normalised x,y cordinates
                ymin,xmin,ymax,xmax=bbox
                #converting them to actual x,y values
                xmin,xmax,ymin,ymax=(xmin*iW,xmax*iW,ymin*iH,ymax*iH)
                #converting flaot to int
                xmin,xmax,ymin,ymax=int(xmin),int(xmax),int(ymin),int(ymax)
    
                cv2.rectangle(image,(xmin,ymin),(xmax,ymax), color=class_color,thickness=2)
                cv2.putText(image,display_text,(xmin,ymin+10),cv2.FONT_HERSHEY_PLAIN,1,class_color,2)
    return image

# %%
# video detection
videoPath = ".\\Video data\\traffic-mini.mp4"

cap = cv2.VideoCapture(videoPath)
if (cap.isOpened() == False) :
    print("Error opening file")
# Read until video is completed 
success, image = cap.read() 
startTime = 0
while success:
    currentTime = time.time()
    # Calculates the FPS. It measures the time taken to process a single frame
    # currentTime-startTime gives the elapsed time between the current frame and the previous frame
    fps = 1/(currentTime-startTime)
    startTime = currentTime
    boxImage = createBoundingBox(image)
    cv2.putText(boxImage, "FPS:"+ str(int(fps)), (20, 70), cv2.FONT_HERSHEY_PLAIN, 2, (0,255,0),2)
    cv2.imshow("Result", boxImage)
    key= cv2.waitKey(1) & 0xFF
    if key == ord("q"):
        break
    (success, image) = cap.read()
cap.release() 
cv2.destroyAllWindows()
# Out:
# class_confidence-- 83
# class_confidence-- 78
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 60
# class_confidence-- 59
# class_confidence-- 82
# class_confidence-- 77
# class_confidence-- 66
# class_confidence-- 66
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 59
# class_confidence-- 51
# class_confidence-- 82
# class_confidence-- 78
# class_confidence-- 67
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 61
# class_confidence-- 60
# class_confidence-- 60
# class_confidence-- 55
# class_confidence-- 83
# class_confidence-- 79
# class_confidence-- 69
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 59
# class_confidence-- 52
# class_confidence-- 83
# class_confidence-- 79
# class_confidence-- 69
# class_confidence-- 69
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 63
# class_confidence-- 62
# class_confidence-- 53
# class_confidence-- 83
# class_confidence-- 79
# class_confidence-- 70
# class_confidence-- 69
# class_confidence-- 69
# class_confidence-- 68
# class_confidence-- 62
# class_confidence-- 62
# class_confidence-- 55
# class_confidence-- 85
# class_confidence-- 80
# class_confidence-- 70
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 63
# class_confidence-- 62
# class_confidence-- 62
# class_confidence-- 58
# class_confidence-- 85
# class_confidence-- 77
# class_confidence-- 71
# class_confidence-- 67
# class_confidence-- 63
# class_confidence-- 61
# class_confidence-- 60
# class_confidence-- 58
# class_confidence-- 57
# class_confidence-- 84
# class_confidence-- 77
# class_confidence-- 69
# class_confidence-- 68
# class_confidence-- 63
# class_confidence-- 62
# class_confidence-- 60
# class_confidence-- 59
# class_confidence-- 53
# class_confidence-- 85
# class_confidence-- 77
# class_confidence-- 69
# class_confidence-- 69
# class_confidence-- 64
# class_confidence-- 62
# class_confidence-- 61
# class_confidence-- 60
# class_confidence-- 52
# class_confidence-- 85
# class_confidence-- 80
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 60
# class_confidence-- 60
# class_confidence-- 85
# class_confidence-- 80
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 60
# class_confidence-- 60
# class_confidence-- 87
# class_confidence-- 80
# class_confidence-- 68
# class_confidence-- 65
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 58
# class_confidence-- 86
# class_confidence-- 79
# class_confidence-- 67
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 57
# class_confidence-- 53
# class_confidence-- 85
# class_confidence-- 78
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 61
# class_confidence-- 51
# class_confidence-- 85
# class_confidence-- 79
# class_confidence-- 70
# class_confidence-- 69
# class_confidence-- 67
# class_confidence-- 64
# class_confidence-- 62
# class_confidence-- 59
# class_confidence-- 53
# class_confidence-- 85
# class_confidence-- 79
# class_confidence-- 71
# class_confidence-- 68
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 62
# class_confidence-- 51
# class_confidence-- 85
# class_confidence-- 79
# class_confidence-- 70
# class_confidence-- 68
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 62
# class_confidence-- 51
# class_confidence-- 87
# class_confidence-- 80
# class_confidence-- 71
# class_confidence-- 68
# class_confidence-- 68
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 86
# class_confidence-- 79
# class_confidence-- 71
# class_confidence-- 66
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 84
# class_confidence-- 80
# class_confidence-- 73
# class_confidence-- 66
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 61
# class_confidence-- 61
# class_confidence-- 83
# class_confidence-- 79
# class_confidence-- 69
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 64
# class_confidence-- 64
# class_confidence-- 58
# class_confidence-- 83
# class_confidence-- 80
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 61
# class_confidence-- 56
# class_confidence-- 83
# class_confidence-- 80
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 61
# class_confidence-- 56
# class_confidence-- 83
# class_confidence-- 79
# class_confidence-- 68
# class_confidence-- 66
# class_confidence-- 66
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 59
# class_confidence-- 57
# class_confidence-- 81
# class_confidence-- 77
# class_confidence-- 68
# class_confidence-- 65
# class_confidence-- 65
# class_confidence-- 63
# class_confidence-- 62
# class_confidence-- 62
# class_confidence-- 57
# class_confidence-- 80
# class_confidence-- 76
# class_confidence-- 69
# class_confidence-- 67
# class_confidence-- 64
# class_confidence-- 64
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 57
# class_confidence-- 80
# class_confidence-- 78
# class_confidence-- 68
# class_confidence-- 65
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 61
# class_confidence-- 53
# class_confidence-- 80
# class_confidence-- 77
# class_confidence-- 68
# class_confidence-- 65
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 61
# class_confidence-- 57
# class_confidence-- 56
# class_confidence-- 80
# class_confidence-- 77
# class_confidence-- 68
# class_confidence-- 65
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 61
# class_confidence-- 57
# class_confidence-- 56
# class_confidence-- 80
# class_confidence-- 80
# class_confidence-- 69
# class_confidence-- 66
# class_confidence-- 62
# class_confidence-- 62
# class_confidence-- 62
# class_confidence-- 61
# class_confidence-- 54
# class_confidence-- 79
# class_confidence-- 79
# class_confidence-- 70
# class_confidence-- 65
# class_confidence-- 63
# class_confidence-- 62
# class_confidence-- 59
# class_confidence-- 59
# class_confidence-- 54
# class_confidence-- 80
# class_confidence-- 78
# class_confidence-- 69
# class_confidence-- 63
# class_confidence-- 62
# class_confidence-- 62
# class_confidence-- 58
# class_confidence-- 54
# class_confidence-- 81
# class_confidence-- 79
# class_confidence-- 71
# class_confidence-- 63
# class_confidence-- 61
# class_confidence-- 60
# class_confidence-- 56
# class_confidence-- 83
# class_confidence-- 78
# class_confidence-- 69
# class_confidence-- 64
# class_confidence-- 64
# class_confidence-- 62
# class_confidence-- 54
# class_confidence-- 53
# class_confidence-- 83
# class_confidence-- 78
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 64
# class_confidence-- 62
# class_confidence-- 54
# class_confidence-- 53
# class_confidence-- 82
# class_confidence-- 78
# class_confidence-- 69
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 61
# class_confidence-- 53
# class_confidence-- 51
# class_confidence-- 82
# class_confidence-- 79
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 63
# class_confidence-- 53
# class_confidence-- 51
# class_confidence-- 83
# class_confidence-- 79
# class_confidence-- 69
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 62
# class_confidence-- 53
# class_confidence-- 51
# class_confidence-- 85
# class_confidence-- 79
# class_confidence-- 69
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 57
# class_confidence-- 51
# class_confidence-- 86
# class_confidence-- 80
# class_confidence-- 69
# class_confidence-- 69
# class_confidence-- 63
# class_confidence-- 63
# class_confidence-- 59
# class_confidence-- 86
# class_confidence-- 80
# class_confidence-- 69
# class_confidence-- 69
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 59
# class_confidence-- 86
# class_confidence-- 80
# class_confidence-- 68
# class_confidence-- 66
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 58
# class_confidence-- 54
# class_confidence-- 87
# class_confidence-- 80
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 56
# class_confidence-- 87
# class_confidence-- 79
# class_confidence-- 68
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 53
# class_confidence-- 51
# class_confidence-- 86
# class_confidence-- 79
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 65
# class_confidence-- 55
# class_confidence-- 52
# class_confidence-- 86
# class_confidence-- 79
# class_confidence-- 73
# class_confidence-- 72
# class_confidence-- 70
# class_confidence-- 66
# class_confidence-- 55
# class_confidence-- 86
# class_confidence-- 79
# class_confidence-- 73
# class_confidence-- 72
# class_confidence-- 70
# class_confidence-- 66
# class_confidence-- 55
# class_confidence-- 86
# class_confidence-- 78
# class_confidence-- 74
# class_confidence-- 73
# class_confidence-- 70
# class_confidence-- 64
# class_confidence-- 59
# class_confidence-- 86
# class_confidence-- 80
# class_confidence-- 73
# class_confidence-- 72
# class_confidence-- 71
# class_confidence-- 65
# class_confidence-- 54
# class_confidence-- 84
# class_confidence-- 79
# class_confidence-- 72
# class_confidence-- 70
# class_confidence-- 69
# class_confidence-- 64
# class_confidence-- 59
# class_confidence-- 52
# class_confidence-- 83
# class_confidence-- 80
# class_confidence-- 71
# class_confidence-- 70
# class_confidence-- 65
# class_confidence-- 63
# class_confidence-- 58
# class_confidence-- 55
# class_confidence-- 84
# class_confidence-- 79
# class_confidence-- 71
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 64
# class_confidence-- 58
# class_confidence-- 57
# class_confidence-- 84
# class_confidence-- 79
# class_confidence-- 71
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 64
# class_confidence-- 58
# class_confidence-- 57
# class_confidence-- 84
# class_confidence-- 79
# class_confidence-- 70
# class_confidence-- 69
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 59
# class_confidence-- 56
# class_confidence-- 85
# class_confidence-- 79
# class_confidence-- 69
# class_confidence-- 67
# class_confidence-- 65
# class_confidence-- 62
# class_confidence-- 58
# class_confidence-- 55
# class_confidence-- 86
# class_confidence-- 78
# class_confidence-- 68
# class_confidence-- 68
# class_confidence-- 66
# class_confidence-- 62
# class_confidence-- 60
# class_confidence-- 51
# class_confidence-- 87
# class_confidence-- 78
# class_confidence-- 69
# class_confidence-- 67
# class_confidence-- 67
# class_confidence-- 62
# class_confidence-- 60
# class_confidence-- 53
# class_confidence-- 88
# class_confidence-- 80
# class_confidence-- 70
# class_confidence-- 68
# class_confidence-- 66
# class_confidence-- 61
# class_confidence-- 60
# class_confidence-- 55
# class_confidence-- 88
# class_confidence-- 80
# class_confidence-- 70
# class_confidence-- 68
# class_confidence-- 66
# class_confidence-- 62
# class_confidence-- 60
# class_confidence-- 54
# class_confidence-- 89
# class_confidence-- 79
# class_confidence-- 71
# class_confidence-- 68
# class_confidence-- 62
# class_confidence-- 61
# class_confidence-- 59
# class_confidence-- 54
# class_confidence-- 88
# class_confidence-- 79
# class_confidence-- 75
# class_confidence-- 69
# class_confidence-- 64
# class_confidence-- 57
# class_confidence-- 56
# class_confidence-- 54
# class_confidence-- 53
# class_confidence-- 87
# class_confidence-- 79
# class_confidence-- 76
# class_confidence-- 68
# class_confidence-- 66
# class_confidence-- 57
# class_confidence-- 54
# class_confidence-- 52
# class_confidence-- 86
# class_confidence-- 79
# class_confidence-- 76
# class_confidence-- 70
# class_confidence-- 68
# class_confidence-- 56
# class_confidence-- 55
# class_confidence-- 52
# class_confidence-- 85
# class_confidence-- 77
# class_confidence-- 76
# class_confidence-- 70
# class_confidence-- 69
# class_confidence-- 57
# class_confidence-- 55
# class_confidence-- 54
# class_confidence-- 85
# class_confidence-- 77
# class_confidence-- 76
# class_confidence-- 70
# class_confidence-- 70
# class_confidence-- 57
# class_confidence-- 54
# class_confidence-- 54
# class_confidence-- 82
# class_confidence-- 77
# class_confidence-- 76
# class_confidence-- 70
# class_confidence-- 69
# class_confidence-- 55
# class_confidence-- 53
# class_confidence-- 52
# class_confidence-- 80
# class_confidence-- 76
# class_confidence-- 76
# class_confidence-- 69
# class_confidence-- 67
# class_confidence-- 58
# class_confidence-- 55
# class_confidence-- 80
# class_confidence-- 77
# class_confidence-- 73
# class_confidence-- 69
# class_confidence-- 67
# class_confidence-- 57
# class_confidence-- 54
# class_confidence-- 82
# class_confidence-- 76
# class_confidence-- 76
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 55
# class_confidence-- 81
# class_confidence-- 76
# class_confidence-- 72
# class_confidence-- 69
# class_confidence-- 68
# class_confidence-- 53
# class_confidence-- 53
# class_confidence-- 81
# class_confidence-- 77
# class_confidence-- 72
# class_confidence-- 69
# class_confidence-- 68
# class_confidence-- 53
# class_confidence-- 53
# class_confidence-- 78
# class_confidence-- 77
# class_confidence-- 71
# class_confidence-- 70
# class_confidence-- 68
# class_confidence-- 53
# class_confidence-- 53
# class_confidence-- 78
# class_confidence-- 78
# class_confidence-- 70
# class_confidence-- 68
# class_confidence-- 65
# class_confidence-- 56
# class_confidence-- 55
# class_confidence-- 79
# class_confidence-- 77
# class_confidence-- 69
# class_confidence-- 68
# class_confidence-- 68
# class_confidence-- 58
# class_confidence-- 56
# class_confidence-- 81
# class_confidence-- 77
# class_confidence-- 71
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 56
# class_confidence-- 54
# class_confidence-- 80
# class_confidence-- 77
# class_confidence-- 74
# class_confidence-- 66
# class_confidence-- 66
# class_confidence-- 56
# class_confidence-- 55
# class_confidence-- 51
# class_confidence-- 80
# class_confidence-- 77
# class_confidence-- 74
# class_confidence-- 66
# class_confidence-- 66
# class_confidence-- 57
# class_confidence-- 55
# class_confidence-- 51
# class_confidence-- 80
# class_confidence-- 77
# class_confidence-- 76
# class_confidence-- 69
# class_confidence-- 65
# class_confidence-- 55
# class_confidence-- 53
# class_confidence-- 53
# class_confidence-- 80
# class_confidence-- 78
# class_confidence-- 76
# class_confidence-- 71
# class_confidence-- 65
# class_confidence-- 54
# class_confidence-- 52
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 83
# class_confidence-- 79
# class_confidence-- 77
# class_confidence-- 70
# class_confidence-- 65
# class_confidence-- 56
# class_confidence-- 54
# class_confidence-- 83
# class_confidence-- 78
# class_confidence-- 76
# class_confidence-- 69
# class_confidence-- 65
# class_confidence-- 57
# class_confidence-- 55
# class_confidence-- 84
# class_confidence-- 78
# class_confidence-- 76
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 58
# class_confidence-- 51
# class_confidence-- 87
# class_confidence-- 77
# class_confidence-- 74
# class_confidence-- 68
# class_confidence-- 63
# class_confidence-- 56
# class_confidence-- 87
# class_confidence-- 78
# class_confidence-- 74
# class_confidence-- 68
# class_confidence-- 63
# class_confidence-- 57
# class_confidence-- 85
# class_confidence-- 78
# class_confidence-- 74
# class_confidence-- 67
# class_confidence-- 63
# class_confidence-- 58
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 86
# class_confidence-- 78
# class_confidence-- 74
# class_confidence-- 65
# class_confidence-- 63
# class_confidence-- 59
# class_confidence-- 86
# class_confidence-- 79
# class_confidence-- 73
# class_confidence-- 65
# class_confidence-- 63
# class_confidence-- 58
# class_confidence-- 87
# class_confidence-- 79
# class_confidence-- 72
# class_confidence-- 67
# class_confidence-- 61
# class_confidence-- 56
# class_confidence-- 51
# class_confidence-- 88
# class_confidence-- 79
# class_confidence-- 72
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 56
# class_confidence-- 52
# class_confidence-- 88
# class_confidence-- 79
# class_confidence-- 72
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 56
# class_confidence-- 52
# class_confidence-- 89
# class_confidence-- 80
# class_confidence-- 70
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 55
# class_confidence-- 52
# class_confidence-- 90
# class_confidence-- 78
# class_confidence-- 70
# class_confidence-- 66
# class_confidence-- 65
# class_confidence-- 56
# class_confidence-- 51
# class_confidence-- 90
# class_confidence-- 79
# class_confidence-- 70
# class_confidence-- 68
# class_confidence-- 62
# class_confidence-- 56
# class_confidence-- 51
# class_confidence-- 91
# class_confidence-- 79
# class_confidence-- 68
# class_confidence-- 66
# class_confidence-- 58
# class_confidence-- 56
# class_confidence-- 51
# class_confidence-- 91
# class_confidence-- 79
# class_confidence-- 69
# class_confidence-- 69
# class_confidence-- 58
# class_confidence-- 54
# class_confidence-- 51
# class_confidence-- 91
# class_confidence-- 79
# class_confidence-- 69
# class_confidence-- 69
# class_confidence-- 58
# class_confidence-- 55
# class_confidence-- 51
# class_confidence-- 91
# class_confidence-- 80
# class_confidence-- 71
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 55
# class_confidence-- 52
# class_confidence-- 91
# class_confidence-- 80
# class_confidence-- 70
# class_confidence-- 68
# class_confidence-- 65
# class_confidence-- 54
# class_confidence-- 54
# class_confidence-- 89
# class_confidence-- 79
# class_confidence-- 71
# class_confidence-- 69
# class_confidence-- 62
# class_confidence-- 57
# class_confidence-- 52
# class_confidence-- 88
# class_confidence-- 79
# class_confidence-- 73
# class_confidence-- 69
# class_confidence-- 62
# class_confidence-- 54
# class_confidence-- 53
# class_confidence-- 87
# class_confidence-- 79
# class_confidence-- 72
# class_confidence-- 67
# class_confidence-- 58
# class_confidence-- 54
# class_confidence-- 54
# class_confidence-- 87
# class_confidence-- 79
# class_confidence-- 72
# class_confidence-- 67
# class_confidence-- 58
# class_confidence-- 54
# class_confidence-- 54
# class_confidence-- 89
# class_confidence-- 79
# class_confidence-- 73
# class_confidence-- 68
# class_confidence-- 63
# class_confidence-- 55
# class_confidence-- 54
# class_confidence-- 87
# class_confidence-- 79
# class_confidence-- 76
# class_confidence-- 68
# class_confidence-- 60
# class_confidence-- 56
# class_confidence-- 55
# class_confidence-- 87
# class_confidence-- 80
# class_confidence-- 75
# class_confidence-- 71
# class_confidence-- 62
# class_confidence-- 56
# class_confidence-- 52
# class_confidence-- 89
# class_confidence-- 80
# class_confidence-- 78
# class_confidence-- 70
# class_confidence-- 62
# class_confidence-- 58
# class_confidence-- 52
# class_confidence-- 90
# class_confidence-- 80
# class_confidence-- 77
# class_confidence-- 68
# class_confidence-- 62
# class_confidence-- 57
# class_confidence-- 53
# class_confidence-- 90
# class_confidence-- 80
# class_confidence-- 77
# class_confidence-- 68
# class_confidence-- 62
# class_confidence-- 58
# class_confidence-- 53
# class_confidence-- 89
# class_confidence-- 82
# class_confidence-- 77
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 60
# class_confidence-- 53
# class_confidence-- 90
# class_confidence-- 82
# class_confidence-- 78
# class_confidence-- 66
# class_confidence-- 65
# class_confidence-- 59
# class_confidence-- 51
# class_confidence-- 90
# class_confidence-- 82
# class_confidence-- 76
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 55
# class_confidence-- 93
# class_confidence-- 83
# class_confidence-- 73
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 53
# class_confidence-- 92
# class_confidence-- 83
# class_confidence-- 73
# class_confidence-- 70
# class_confidence-- 65
# class_confidence-- 92
# class_confidence-- 83
# class_confidence-- 73
# class_confidence-- 71
# class_confidence-- 65
# class_confidence-- 90
# class_confidence-- 82
# class_confidence-- 71
# class_confidence-- 69
# class_confidence-- 60
# class_confidence-- 52
# class_confidence-- 90
# class_confidence-- 83
# class_confidence-- 69
# class_confidence-- 67
# class_confidence-- 63
# class_confidence-- 55
# class_confidence-- 89
# class_confidence-- 83
# class_confidence-- 71
# class_confidence-- 68
# class_confidence-- 59
# class_confidence-- 56
# class_confidence-- 85
# class_confidence-- 83
# class_confidence-- 72
# class_confidence-- 69
# class_confidence-- 59
# class_confidence-- 56
# class_confidence-- 51
# class_confidence-- 86
# class_confidence-- 83
# class_confidence-- 72
# class_confidence-- 71
# class_confidence-- 59
# class_confidence-- 59
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 84
# class_confidence-- 83
# class_confidence-- 72
# class_confidence-- 71
# class_confidence-- 59
# class_confidence-- 58
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 51
# class_confidence-- 85
# class_confidence-- 82
# class_confidence-- 72
# class_confidence-- 71
# class_confidence-- 58
# class_confidence-- 57
# class_confidence-- 51
# class_confidence-- 51
# class_confidence-- 81
# class_confidence-- 79
# class_confidence-- 72
# class_confidence-- 71
# class_confidence-- 58
# class_confidence-- 58
# class_confidence-- 82
# class_confidence-- 81
# class_confidence-- 73
# class_confidence-- 71
# class_confidence-- 57
# class_confidence-- 55
# class_confidence-- 82
# class_confidence-- 80
# class_confidence-- 71
# class_confidence-- 69
# class_confidence-- 58
# class_confidence-- 56
# class_confidence-- 83
# class_confidence-- 78
# class_confidence-- 72
# class_confidence-- 69
# class_confidence-- 57
# class_confidence-- 54
# class_confidence-- 83
# class_confidence-- 78
# class_confidence-- 72
# class_confidence-- 69
# class_confidence-- 57
# class_confidence-- 55
# class_confidence-- 83
# class_confidence-- 82
# class_confidence-- 70
# class_confidence-- 66
# class_confidence-- 54
# class_confidence-- 54
# class_confidence-- 52
# class_confidence-- 82
# class_confidence-- 82
# class_confidence-- 71
# class_confidence-- 65
# class_confidence-- 54
# class_confidence-- 53
# class_confidence-- 51
# class_confidence-- 80
# class_confidence-- 79
# class_confidence-- 72
# class_confidence-- 63
# class_confidence-- 53
# class_confidence-- 53
# class_confidence-- 53
# class_confidence-- 52
# class_confidence-- 85
# class_confidence-- 81
# class_confidence-- 73
# class_confidence-- 63
# class_confidence-- 58
# class_confidence-- 56
# class_confidence-- 52
# class_confidence-- 52
# class_confidence-- 83
# class_confidence-- 82
# class_confidence-- 74
# class_confidence-- 62
# class_confidence-- 58
# class_confidence-- 56
# class_confidence-- 53
# class_confidence-- 84
# class_confidence-- 82
# class_confidence-- 73
# class_confidence-- 61
# class_confidence-- 58
# class_confidence-- 56
# class_confidence-- 53
# class_confidence-- 84
# class_confidence-- 82
# class_confidence-- 74
# class_confidence-- 62
# class_confidence-- 59
# class_confidence-- 57
# class_confidence-- 53
# class_confidence-- 83
# class_confidence-- 83
# class_confidence-- 72
# class_confidence-- 65
# class_confidence-- 63
# class_confidence-- 57
# class_confidence-- 54
# class_confidence-- 83
# class_confidence-- 78
# class_confidence-- 70
# class_confidence-- 69
# class_confidence-- 62
# class_confidence-- 55
# class_confidence-- 53
# class_confidence-- 53
# class_confidence-- 83
# class_confidence-- 73
# class_confidence-- 69
# class_confidence-- 65
# class_confidence-- 64
# class_confidence-- 60
# class_confidence-- 55
# class_confidence-- 52
# class_confidence-- 83
# class_confidence-- 72
# class_confidence-- 71
# class_confidence-- 67
# class_confidence-- 63
# class_confidence-- 58
# class_confidence-- 58
# class_confidence-- 52
# class_confidence-- 83
# class_confidence-- 72
# class_confidence-- 71
# class_confidence-- 67
# class_confidence-- 64
# class_confidence-- 58
# class_confidence-- 57
# class_confidence-- 52
# class_confidence-- 83
# class_confidence-- 73
# class_confidence-- 70
# class_confidence-- 68
# class_confidence-- 61
# class_confidence-- 60
# class_confidence-- 58
# class_confidence-- 53
# class_confidence-- 83
# class_confidence-- 74
# class_confidence-- 71
# class_confidence-- 69
# class_confidence-- 64
# class_confidence-- 58
# class_confidence-- 58
# class_confidence-- 53
# class_confidence-- 83
# class_confidence-- 73
# class_confidence-- 71
# class_confidence-- 68
# class_confidence-- 64
# class_confidence-- 60
# class_confidence-- 57
# class_confidence-- 55
# class_confidence-- 52
# class_confidence-- 84
# class_confidence-- 71
# class_confidence-- 70
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 61
# class_confidence-- 60
# class_confidence-- 57
# class_confidence-- 54
# class_confidence-- 84
# class_confidence-- 69
# class_confidence-- 68
# class_confidence-- 68
# class_confidence-- 63
# class_confidence-- 61
# class_confidence-- 55
# class_confidence-- 55
# class_confidence-- 55
# class_confidence-- 84
# class_confidence-- 69
# class_confidence-- 68
# class_confidence-- 68
# class_confidence-- 62
# class_confidence-- 61
# class_confidence-- 55
# class_confidence-- 55
# class_confidence-- 54
# class_confidence-- 82
# class_confidence-- 68
# class_confidence-- 68
# class_confidence-- 66
# class_confidence-- 63
# class_confidence-- 61
# class_confidence-- 52
# class_confidence-- 52
# class_confidence-- 82
# class_confidence-- 68
# class_confidence-- 68
# class_confidence-- 67
# class_confidence-- 63
# class_confidence-- 57
# class_confidence-- 54
# class_confidence-- 53
# class_confidence-- 83
# class_confidence-- 68
# class_confidence-- 66
# class_confidence-- 66
# class_confidence-- 62
# class_confidence-- 56
# class_confidence-- 52
# class_confidence-- 52
# class_confidence-- 83
# class_confidence-- 67
# class_confidence-- 66
# class_confidence-- 64
# class_confidence-- 63
# class_confidence-- 58
# class_confidence-- 54
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 83
# class_confidence-- 71
# class_confidence-- 70
# class_confidence-- 65
# class_confidence-- 63
# class_confidence-- 59
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 51
# class_confidence-- 83
# class_confidence-- 71
# class_confidence-- 70
# class_confidence-- 65
# class_confidence-- 63
# class_confidence-- 59
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 51
# class_confidence-- 82
# class_confidence-- 73
# class_confidence-- 72
# class_confidence-- 65
# class_confidence-- 60
# class_confidence-- 58
# class_confidence-- 54
# class_confidence-- 52
# class_confidence-- 83
# class_confidence-- 73
# class_confidence-- 72
# class_confidence-- 66
# class_confidence-- 59
# class_confidence-- 58
# class_confidence-- 52
# class_confidence-- 52
# class_confidence-- 82
# class_confidence-- 74
# class_confidence-- 72
# class_confidence-- 67
# class_confidence-- 58
# class_confidence-- 58
# class_confidence-- 54
# class_confidence-- 82
# class_confidence-- 74
# class_confidence-- 70
# class_confidence-- 67
# class_confidence-- 61
# class_confidence-- 58
# class_confidence-- 51
# class_confidence-- 82
# class_confidence-- 74
# class_confidence-- 72
# class_confidence-- 65
# class_confidence-- 61
# class_confidence-- 59
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 82
# class_confidence-- 74
# class_confidence-- 72
# class_confidence-- 65
# class_confidence-- 61
# class_confidence-- 59
# class_confidence-- 51
# class_confidence-- 51
# class_confidence-- 82
# class_confidence-- 75
# class_confidence-- 69
# class_confidence-- 64
# class_confidence-- 62
# class_confidence-- 60
# class_confidence-- 53
# class_confidence-- 51
# class_confidence-- 83
# class_confidence-- 77
# class_confidence-- 72
# class_confidence-- 67
# class_confidence-- 62
# class_confidence-- 61
# class_confidence-- 57
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 80
# class_confidence-- 76
# class_confidence-- 73
# class_confidence-- 66
# class_confidence-- 60
# class_confidence-- 54
# class_confidence-- 51
# class_confidence-- 81
# class_confidence-- 76
# class_confidence-- 73
# class_confidence-- 67
# class_confidence-- 57
# class_confidence-- 56
# class_confidence-- 53
# class_confidence-- 81
# class_confidence-- 76
# class_confidence-- 73
# class_confidence-- 67
# class_confidence-- 54
# class_confidence-- 81
# class_confidence-- 76
# class_confidence-- 73
# class_confidence-- 66
# class_confidence-- 54
# class_confidence-- 51
# class_confidence-- 81
# class_confidence-- 75
# class_confidence-- 74
# class_confidence-- 68
# class_confidence-- 58
# class_confidence-- 53
# class_confidence-- 81
# class_confidence-- 76
# class_confidence-- 71
# class_confidence-- 66
# class_confidence-- 58
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 81
# class_confidence-- 76
# class_confidence-- 72
# class_confidence-- 70
# class_confidence-- 54
# class_confidence-- 52
# class_confidence-- 80
# class_confidence-- 78
# class_confidence-- 71
# class_confidence-- 68
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 81
# class_confidence-- 79
# class_confidence-- 73
# class_confidence-- 71
# class_confidence-- 59
# class_confidence-- 54
# class_confidence-- 53
# class_confidence-- 81
# class_confidence-- 78
# class_confidence-- 73
# class_confidence-- 71
# class_confidence-- 59
# class_confidence-- 54
# class_confidence-- 53
# class_confidence-- 80
# class_confidence-- 78
# class_confidence-- 77
# class_confidence-- 72
# class_confidence-- 71
# class_confidence-- 54
# class_confidence-- 53
# class_confidence-- 53
# class_confidence-- 80
# class_confidence-- 78
# class_confidence-- 78
# class_confidence-- 72
# class_confidence-- 61
# class_confidence-- 55
# class_confidence-- 54
# class_confidence-- 52
# class_confidence-- 81
# class_confidence-- 76
# class_confidence-- 76
# class_confidence-- 71
# class_confidence-- 63
# class_confidence-- 57
# class_confidence-- 55
# class_confidence-- 53
# class_confidence-- 52
# class_confidence-- 82
# class_confidence-- 79
# class_confidence-- 77
# class_confidence-- 70
# class_confidence-- 58
# class_confidence-- 54
# class_confidence-- 53
# class_confidence-- 53
# class_confidence-- 52
# class_confidence-- 52
# class_confidence-- 82
# class_confidence-- 78
# class_confidence-- 75
# class_confidence-- 70
# class_confidence-- 57
# class_confidence-- 56
# class_confidence-- 55
# class_confidence-- 55
# class_confidence-- 54
# class_confidence-- 82
# class_confidence-- 78
# class_confidence-- 75
# class_confidence-- 70
# class_confidence-- 57
# class_confidence-- 56
# class_confidence-- 55
# class_confidence-- 54
# class_confidence-- 54
# class_confidence-- 82
# class_confidence-- 79
# class_confidence-- 74
# class_confidence-- 68
# class_confidence-- 57
# class_confidence-- 56
# class_confidence-- 56
# class_confidence-- 53
# class_confidence-- 52
# class_confidence-- 52
# class_confidence-- 81
# class_confidence-- 79
# class_confidence-- 72
# class_confidence-- 68
# class_confidence-- 57
# class_confidence-- 56
# class_confidence-- 54
# class_confidence-- 52
# class_confidence-- 51
# class_confidence-- 82
# class_confidence-- 79
# class_confidence-- 73
# class_confidence-- 66
# class_confidence-- 58
# class_confidence-- 57
# class_confidence-- 51
# class_confidence-- 82
# class_confidence-- 81
# class_confidence-- 72
# class_confidence-- 66
# class_confidence-- 58
# class_confidence-- 58
# class_confidence-- 52
